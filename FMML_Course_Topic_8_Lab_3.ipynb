# %% [markdown]
# <a href="https://colab.research.google.com/github/revathi2308/jubhidha/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 03:36:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   205MB/s    in 0.3s
#
# 2024-04-01 03:36:44 (205 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21888   1408.0337v1  A large amount of observational data has been ...  stat
# 32656   1411.1490v2  It has been a long-standing goal in machine le...    cs
# 34717  1711.01563v1  Manually labeling documents is tedious and exp...    cs
# 7099   1710.04373v1  The project aims to research on combining deep...  stat
# 11569  1606.03623v1  A key goal of computational personalized medic...  stat
# ...             ...                                                ...   ...
# 6313   1611.02221v2  We consider semi-supervised regression when th...  stat
# 21932  1503.08356v4  Low-rank representation~(LRR) has been a signi...  stat
# 1049   1610.06258v3  Until recently, research on artificial neural ...  stat
# 3461   1706.04572v1  We present a solution to "Google Cloud and You...  stat
# 5100    1104.1550v2  We present a novel bio-inspired and dynamic co...    cs
#
#                                                    title  year  \
# 21888  A Bayesian estimation approach to analyze non-...  2014
# 32656  Efficient Representations for Life-Long Learni...  2014
# 34717  Multi-label Dataless Text Classification with ...  2017
# 7099   Deep Learning in Multiple Multistep Time Serie...  2017
# 11569  Drug response prediction by inferring pathway-...  2016
# ...                                                  ...   ...
# 6313   Minimax-optimal semi-supervised regression on ...  2016
# 21932  Efficient Online Minimization for Low-Rank Sub...  2015
# 1049     Using Fast Weights to Attend to the Recent Past  2016
# 3461   Deep Learning Methods for Efficient Large Scal...  2017
# 5100   A bio-inspired image coder with temporal scala...  2011
#
#                                                 keywords
# 21888  [observational, accumulated, generating, proce...
# 32656  [generally, different, efficient, algorithms, ...
# 34717  [documents, expensive, essential, traditional,...
# 7099   [combining, specifically, statistics, multiste...
# 11569  [computational, personalized, systematically, ...
# ...                                                  ...
# 6313   [supervised, regression, predictor, variables,...
# 21932  [significant, segmenting, generated, subspaces...
# 1049   [artificial, restricted, activities, represent...
# 3461   [understanding, challenge, performed, augmente...
# 5100   [reproducing, processing, mammalian, scalabili...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21888    [observational, accumulated, generating, proce...
# 32656    [generally, different, efficient, algorithms, ...
# 34717    [documents, expensive, essential, traditional,...
# 7099     [combining, specifically, statistics, multiste...
# 11569    [computational, personalized, systematically, ...
#                                ...
# 7655     [variational, autoencoder, generative, increas...
# 14866    [extracting, translations, morphologically, co...
# 33311    [handwritten, alphabetical, character, recogni...
# 36963    [representation, linearizes, remaining, deform...
# 8416     [supervised, technique, summarizing, automatic...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8902 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="46010de3-be8e-44ef-891b-3a1280c13c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46010de3-be8e-44ef-891b-3a1280c13c29")) {                    Plotly.newPlot(                        "46010de3-be8e-44ef-891b-3a1280c13c29",                        [{"x":["variables","influences","procedure","framework","estimation","accumulated","gaussianity","processes","generating","observational","subsequent","representations","commonality","subspaces","autoencoding","generally","autoencoders","functions","algorithms","commonalities","nonlinear","additionally","different","initially","constructing","efficiently","dimensional","theoretical","specifically","combinations","interpretation","efficient","assumption","formulations","algorithm","classifier","categories","documents","expensive","alternatives","belonging","associated","accommodate","explicitly","essential","threshold","traditional","automatically","supervision","experiments","collection","classification","scenarios","restricted","supervised","smoothing","solutions","techniques","generalized","outperforms","incorporate","inference","fluctuate","statistics","forecasting","combining","thoroughly","seasonality","competition","illustrate","prediction","variation","utilizing","opportunity","personalized","previously","inhibitors","systematically","formulation","therapies","individual","heterogeneity","effectively","extremely","integration","challenging","validated","mechanisms","component","responses","practical","elucidating","meaningful","quantitatively","inferring","predictions","hypotheses","demonstrate","associations","available","information","biologically","developing","predicting","kernelized","computational","especially","selecting","selective","synthetic","applicability","molecular","knowledge","factorization","brightness","minimizing","applications","distribution","adversarial","sometimes","partially","penalties","identifier","following","condition","interventions","consistency","typically","robustness","distinguish","regression","orthogonal","substantially","influence","equivalent","conditional","statistical","similarity","likelihood","validation","selection","introduce","clustering","coordinate","quadratic","optimization","precision","estimates","parameter","shrinkage","penalized","discriminant","computing","probability","consisting","complexity","consumption","intrinsic","sensitive","simulation","decoupled","implementations","frequency","resiliency","performance","practically","operating","therefore","substantial","degradation","predictive","platforms","perturbations","indicates","susceptible","increased","significant","conventional","architecture","reduction","inadequacies","widespread","artificial","sensitivity","designing","recognition","significance","development","guesswhat","attention","candidates","expressions","explainable","achieving","attracted","descriptions","beforehand","discovery","benchmarked","furthermore"],"y":[122,7,105,547,201,5,0,117,105,5,36,251,1,19,1,72,21,211,610,4,47,64,751,20,38,131,192,158,195,42,61,408,68,22,796,158,66,71,64,33,12,112,9,81,64,33,178,189,48,603,70,501,84,49,211,20,168,371,72,258,59,200,1,54,12,96,8,0,36,84,211,57,34,14,21,96,1,18,86,0,124,5,108,46,54,267,40,56,99,34,116,0,58,23,25,87,33,517,9,307,674,12,58,81,6,254,130,49,15,136,38,11,355,32,2,56,401,201,99,26,55,7,2,92,47,4,56,114,103,32,108,13,29,67,55,94,140,152,59,41,176,339,156,15,30,308,62,76,112,2,6,22,136,171,59,217,19,46,64,97,4,30,80,1,847,17,25,159,42,17,42,30,15,23,7,32,238,103,253,113,3,11,142,34,47,378,19,109,2,146,29,44,4,79,30,52,7,56,4,179],"type":"bar"},{"x":["variables","influences","procedure","framework","estimation","accumulated","gaussianity","process ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Warehouse</span> <span style=''>Layout</span> <span style=''>Method</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>Ant</span> <span style=''>Colony</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>Backtracking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Warehouse</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>a</span> <span style=''>company</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Warehouse</span> <span style='background-color:rgba(0, 255, 0, 0.5686274509803921);'>Management</span> <span style=''>System</span> <span style=''>(WMS)</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>function</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>layout</span> <span style=''>of</span> <span style=''>the</span> <span style=''>storage</span> <span style=''>goods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>improved</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>warehouse</span> <span style=''>layout</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>ant</span> <span style=''>colony</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>backtracking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style=''>method</span> <span style=''>works</span> <span style=''>on</span> <span style=''>two</span> <span style=''>steps</span> <span style=''>First</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.5333333333333334);'>generates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.30232558139534876);'>solutions</span> <span style='background-color:rgba(255, 0, 0, 0.3372781065088758);'>parameter</span> <span style=''>tree</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>backtracking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Then</span> <span style=''>second</span> <span style=''>it</span> <span style=''>deducts</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.30232558139534876);'>solutions</span> <span style='background-color:rgba(255, 0, 0, 0.3372781065088758);'>parameter</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>ant</span> <span style=''>colony</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>backtracking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>This</span> <span style=''>method</span> <span style=''>was</span> <span style=''>tested</span> <span style=''>by</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Survey</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbalanced</span> <span style=''>datasets</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>need</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imbalance</span> <span style=''>between</span> <span style=''>classes</span> <span style=''>Often</span> <span style=''>it</span> <span style=''>is</span> <span style=''>desired</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style=''>high</span> <span style=''>recall</span> <span style=''>on</span> <span style=''>the</span> <span style=''>minority</span> <span style=''>class</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>on</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>class</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>review</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>proposed</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbalanced</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>study</span> <span style=''>their</span> <span style=''>effect</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Group</span> <span style=''>Sparse</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>Hardness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relaxations</span> <br/><br/><span style=''>Group</span> <span style=''>based</span> <span style=''>sparsity</span> <span style=''>models</span> <span style=''>are</span> <span style=''>proven</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>instrumental</span> <span style=''>in</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.5344827586206896);'>regression</span> <span style=''>problems</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recovering</span> <span style=''>signals</span> <span style=''>from</span> <span style=''>much</span> <span style=''>fewer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>than</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compressive</span> <span style=''>sensing</span> <span style=''>The</span> <span style=''>main</span> <span style=''>promise</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>is</span> <span style=''>the</span> <span style=''>recovery</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.30508474576271194);'>interpretable</span> <span style=''>signals</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.30994152046783624);'>identification</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constituent</span> <span style=''>groups</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.4108527131782945);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>group</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>problems</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlight</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractability</span> <span style=''>issues</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>group</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>weighted</span> <span style=''>maximum</span> <span style=''>coverage</span> <span style=''>problem</span> <span style=''>(WMC)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Leveraging</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>group</span> <span style=''>models</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>group</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>which</span> <span style=''>enable</span> <span style=''>correct</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>General</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>of</span> <span style=''>Dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Certificate</span> <span style=''>Analysis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structured</span> <span style=''>Sparse</span> <span style=''>Recovery</span> <span style=''>Problems</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>develops</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparse</span> <span style=''>recovery</span> <span style=''>problems</span> <span style=''>using</span> <span style=''>the</span> <span style=''>notation</span> <span style=''>of</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>certificate</span> <span style=''>Although</span> <span style=''>certain</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>certificate</span> <span style=''>idea</span> <span style=''>have</span> <span style=''>already</span> <span style=''>been</span> <span style=''>used</span> <span style=''>in</span> <span style=''>some</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>a</span> <span style=''>general</span> <span style=''>and</span> <span style=''>coherent</span> <span style=''>theory</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>has</span> <span style=''>so</span> <span style=''>far</span> <span style=''>only</span> <span style=''>been</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>in</span> <span style=''>limited</span> <span style=''>scopes</span> <span style=''>for</span> <span style=''>specific</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>context</span> <span style=''>the</span> <span style=''>current</span> <span style=''>paper</span> <span style=''>makes</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>First</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>certificate</span> <span style=''>which</span> <span style=''>we</span> <span style=''>then</span> <span style=''>use</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>unified</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>recovery</span> <span style=''>analysis</span> <span style=''>for</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>Lasso</span> <span style=''>for</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.048461266360099044)
# 	experimental (0.13123452423063317)
# 	information (0.23841528121683764)
# 	knowledge (0.1255748142907676)
# 	architecture (0.08949416342412451)
# 	segmentation (0.07392996108949416)
# 	detection (0.11743898125221082)
# 	different (0.26565263530244076)
# 	convolutional (0.12911213300318358)
# 	recognition (0.13371064732932436)
#
# Some Statistics words are:
# 	theoretical (0.15103902686264573)
# 	variables (0.1403953370501774)
# 	stochastic (0.1454637607704004)
# 	estimation (0.17638114546376077)
# 	statistical (0.15661429295489102)
# 	distribution (0.183476938672073)
# 	algorithm (0.40496705524581855)
# 	dimensional (0.1926001013684744)
# 	inference (0.2002027369488089)
# 	regression (0.1804358844399392)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e189e10c-45f6-4ea6-9df8-e66d58c1b2b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e189e10c-45f6-4ea6-9df8-e66d58c1b2b4")) {                    Plotly.newPlot(                        "e189e10c-45f6-4ea6-9df8-e66d58c1b2b4",                        [{"x":["variables","influences","procedure","framework","estimation","accumulated","gaussianity","processes","generating","observational","subsequent","representations","commonality","subspaces","autoencoding","generally","autoencoders","functions","algorithms","commonalities","nonlinear","additionally","different","initially","constructing","efficiently","dimensional","theoretical","specifically","combinations","interpretation","efficient","assumption","formulations","algorithm","classifier","categories","documents","expensive","alternatives","belonging","associated","accommodate","explicitly","essential","threshold","traditional","automatically","supervision","experiments","collection","classification","scenarios","restricted","supervised","smoothing","solutions","techniques","generalized","outperforms","incorporate","inference","fluctuate","statistics","forecasting","combining","thoroughly","seasonality","competition","illustrate","prediction","variation","utilizing","opportunity","personalized","previously","inhibitors","systematically","formulation","therapies","individual","heterogeneity","effectively","extremely","integration","challenging","validated","mechanisms","component","responses","practical","elucidating","meaningful","quantitatively","inferring","predictions","hypotheses","demonstrate","associations","available","information","biologically","developing","predicting","kernelized","computational","especially","selecting","selective","synthetic","applicability","molecular","knowledge","factorization","brightness","minimizing","applications","distribution","adversarial","sometimes","partially","penalties","identifier","following","condition","interventions","consistency","typically","robustness","distinguish","regression","orthogonal","substantially","influence","equivalent","conditional","statistical","similarity","likelihood","validation","selection","introduce","clustering","coordinate","quadratic","optimization","precision","estimates","parameter","shrinkage","penalized","discriminant","computing","probability","consisting","complexity","consumption","intrinsic","sensitive","simulation","decoupled","implementations","frequency","resiliency","performance","practically","operating","therefore","substantial","degradation","predictive","platforms","perturbations","indicates","susceptible","increased","significant","conventional","architecture","reduction","inadequacies","widespread","artificial","sensitivity","designing","recognition","significance","development","guesswhat","attention","candidates","expressions","explainable","achieving","attracted","descriptions","beforehand","discovery","benchmarked","furthermore","recurrent","expression","according","capability","recognising","delineated","referring","subjective","representation","identified","background","prototype","sufficiently","maximally","informative","principled","construct","exploratory","fundamental","projections","constraints","formalized","visualizations","interactive","intuitive","theoretic","exploration","predefined","graphical","nonparanormal","nonparametric","convergence","coefficient","correlation","parametric","replacement","spearmans","estimating","undirected","including","estimators","semiparametric","subsequently","extension","empirical","neighborhood","parameters","characterization","sequentially","structure","classical","exhaustive","specialize","comparison","transparent","considered"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	gaussianity
# 	seasonality
# 	therapies
# 	elucidating
# 	nonparanormal
# 	adaboosts
# 	absolutely
# 	calculable
# 	ancestral
# 	independences
# 	debiasing
# 	normalizer
# 	subsamples
# 	emphdirectly
# 	permitted
# 	censoring
# 	confounders
# 	contamination
# 	decontamination
# 	sequentialized
# Some words which never appear in Statistics papers:
# 	inadequacies
# 	guesswhat
# 	benchmarked
# 	delineated
# 	multidisciplinary
# 	incredible
# 	controllers
# 	comprising
# 	pragmatic
# 	predicates
# 	sentences
# 	embodiment
# 	attracting
# 	persistency
# 	deblocking
# 	administered
# 	constantly
# 	ethnicity
# 	dempsters
# 	redistribution

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0456234391179874e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
